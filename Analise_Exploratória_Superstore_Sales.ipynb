# %% [markdown]
# <a href="https://colab.research.google.com/github/michelprosite/Analise-Exploratoria-Superstore-Sales/blob/main/Analise_Explorat%C3%B3ria_Superstore_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória de Dados
#
# > Link dos dados: https://community.tableau.com/s/question/0D54T00000CWeX8SAL/sample-superstore-sales-excelxls

# %%
# Importando as bibliotecas
import numpy as np
import seaborn as sns
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# * Carregando os dados

# %%
df = pd.read_excel("/content/sample-superstore.xls")

# %% [markdown]
# * Verificando o total de linhas e colunas

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# * Impriminfo as 5 primeiras linhas

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# * Imprimindo as 5 últimas linhas

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# * Imprimindo os nomes das colunas

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# * Analisando a typagem de cada coluna

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# * Analisando as estatísticas descritivas da coluna "Sales"

# %%
df['Sales'].describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %% [markdown]
# * Verificando a existência de dados duplicados

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Verificando a existência de dados nulos

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# ***

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## Perguntas de Negócio

# %% [markdown]
# ### 1- Qual cidade com maior valor de vanda de produtos da categoria 'Office Supplies'?

# %%
df_city_plus = df[df['Category'] == 'Office Supplies']
df_city_plus.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name   Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...  14.620         2
# 4                     Eldon Fold 'N Roll Cart System  22.368         2
#
#    Discount  Profit
# 2       0.0  6.8714
# 4       0.2  2.5164
#
# [2 rows x 21 columns]

# %%
df_city_plus_total = df_city_plus.groupby('City')['Sales'].sum()
df_city_plus_total.idxmax()
# Out:
# 'New York City'

# %% [markdown]
# * Convertendo a coluna "Order Date" que está como object, para date

# %%
df['Order Date'] = df['Order Date'].astype('datetime64[ns]')

# %% [markdown]
# ### 2- Qual o total de vendas por data do pedido?

# %%
df_date_order = df.groupby('Order Date')['Sales'].sum()

plt.figure(figsize = (20,6))
df_date_order.plot(x = 'Orders Date', y = 'Sales', color = 'blue')
plt.title('All Sales for Date')
plt.show()

# %% [markdown]
# ### 3- Qual o total de vendas por estado?

# %%
df_date_state = df.groupby('State')['Sales'].sum().reset_index()

plt.figure(figsize = (20,6))
sns.barplot(data = df_date_state,
            y = 'Sales',
            x = 'State').set(title = 'Sales for State')
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# ### 4- Quais são as 10 cidades com maior número de vendas no total?

# %%
df_date_city = df.groupby('City')['Sales'].sum().reset_index()
df_date_city.sort_values('Sales', ascending=False, inplace=True)

plt.figure(figsize = (20,6))
sns.barplot(data = df_date_city.head(10),
            y = 'Sales',
            x = 'City').set(title = 'Sales for City')
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ### 5- Qual seguimento teve o maior número de vendas no total?

# %%
df_sum_segment = df.groupby('Segment')['Sales'].sum().reset_index()

plt.figure(figsize=(10, 10))
plt.pie(df_sum_segment['Sales'],
        labels = df_sum_segment['Segment'],
        startangle = 90)
plt.show()

# %% [markdown]
# ### 6- Qual o total de vendas por ano e por seguimento?

# %%
df['Order_Year'] = df['Order Date'].dt.year
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  South
# 1   Claire Gute  Consumer  United States  Henderson  ...  South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
#
#    Discount    Profit  Order_Year
# 0       0.0   41.9136        2016
# 1       0.0  219.5820        2016
#
# [2 rows x 22 columns]

# %%
df_sales_year = df.groupby(['Order_Year', 'Segment'])['Sales'].sum().reset_index()
df_sales_year
# Out:
#     Order_Year      Segment        Sales
# 0         2014     Consumer  266096.8126
# 1         2014    Corporate  128434.8737
# 2         2014  Home Office   89715.8118
# 3         2015     Consumer  266535.9333
# 4         2015    Corporate  128757.3069
# 5         2015  Home Office   75239.2688
# 6         2016     Consumer  296863.8992
# 7         2016    Corporate  207106.3618
# 8         2016  Home Office  105235.3370
# 9         2017     Consumer  331904.6999
# 10        2017    Corporate  241847.8244
# 11        2017  Home Office  159462.7309

# %% [markdown]
# ### 7.1- Os gestores da empresa estão considerando conceder descontos e gostariam de fazer uma simulação com base nas seguintes regras:
#
# * Se o valor das vendas forem maior que 1000 recebe 15% de desconto
# * Se o valor das vendas forem menor que 1000 recebe 10% de desconto

# %%
df['Desconto(%)'] = df['Sales'].map(lambda x: 15 if x > 1000 else 10)
df.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ...  \
# 0      Claire Gute   Consumer  United States    Henderson  ...
# 1      Claire Gute   Consumer  United States    Henderson  ...
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# ...

# %% [markdown]
# ### 7.2- Quantas vendas receberam 15% de desconto?

# %%
total = (df['Desconto(%)'] == 15).sum()
print(f'O Total de vendas com 15% de desconto é: {total}')
# Out:
# O Total de vendas com 15% de desconto é: 468

# %% [markdown]
# ### 8- Considere que a empresa decida conceder o desconto de 15% do item anterior. Qual seria a média de valor de vendas e depois do desconto?

# %%
df_15 = df[df["Desconto(%)"] == 15]
df_15['Venda_Com_Desconto'] = df['Sales'] - (df_15['Desconto(%)'] / 100 * df_15['Sales'])
df_15.head(3)
# Out:
# <ipython-input-389-87959009699d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_15['Venda_Com_Desconto'] = df['Sales'] - (df_15['Desconto(%)'] / 100 * df_15['Sales'])
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 10      11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 24      25  CA-2015-106320 2015-09-25 2015-09-30  Standard Class    EB-13870
# 27      28  US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
#
#       Customer Name   Segment        Country          City  ...   Category  \
# 10  Brosina Hoffman  Consumer  United States   Los Angeles  ...  Furniture
# 24      Emily Burns  Consumer  United States          Orem  ...  Furniture
# ...

# %%
# Média de valor de vendas
media_vendas = df_15['Sales'].mean()
media_desc = df_15['Venda_Com_Desconto'].mean()
print(f'A média de vendas sem desconto seria: {media_vendas:.2f}')
print(f'A média de vendas com desconto seria: {media_desc:.2f}')
# Out:
# A média de vendas sem desconto seria: 2115.75
# A média de vendas com desconto seria: 1798.38

# %% [markdown]
# ### 9- Qual a média de vendas por seguimento, Por ano e Por Mês?

# %%
df['Month'] = df['Order Date'].dt.month
df_media = df.groupby(['Order_Year', 'Month', 'Segment'])['Sales'].agg([np.sum, np.mean, np.median])
df_media
# Out:
#                                      sum        mean  median
# Order_Year Month Segment
# 2014       1     Consumer      6927.8170  141.384020  32.340
#                  Corporate     1701.5280  130.886769  51.940
#                  Home Office   5607.5500  329.855882  62.820
#            2     Consumer      3167.8540  117.327926  22.776
#                  Corporate     1183.6680   98.639000  73.460
# ...                                  ...         ...     ...
# 2017       11    Corporate    44644.0762  338.212698  79.975
#                  Home Office  24013.6840  245.037592  54.656
#            12    Consumer     50232.4558  186.737754  52.776
#                  Corporate    20524.4320  153.167403  46.460
#                  Home Office  13072.4310  221.566627  50.040
#
# [144 rows x 3 columns]

# %%
anos = df_media.index.get_level_values(0)
meses = df_media.index.get_level_values(1)
segmentos = df_media.index.get_level_values(2)

# %%
plt.figure(figsize = (12,6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                   data = df_media,
                   y = 'mean',
                   x = meses,
                   hue = 'Segment',
                   col = anos,
                   col_wrap = 4)
plt.show()
